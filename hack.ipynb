# %% [markdown]
# Its a database of the salary and benefits paid to City employees since fiscal year 2013. This data is summarized and presented on the Employee Compensation report hosted at http://openbook.sfgov.org. The features of dataset are as given below -
#
# Year Type - Fiscal (July through June) or Calendar (January through December)
#
# Year - An accounting period of 12 months. The City and County of San Francisco operates on a fiscal year that begins on July 1 and ends on June 30 the following year. The Fiscal Year ending June 30, 2012 is represented as FY 2011-2012.
#
# Organization Group Code - Org Group is a group of Departments. For example, the Public Protection Org Group includes departments such as the Police, Fire, Adult Probation, District Attorney, and Sheriff.
#
# Organization Group - Org Group is a group of Departments. For example, the Public Protection Org Group includes departments such as the Police, Fire, Adult Probation, District Attorney, and Sheriff.
#
# Department Code- Departments are the primary organizational unit used by the City and County of San Francisco. Examples include Recreation and Parks, Public Works, and the Police Department.
#
# Department - Departments are the primary organizational unit used by the City and County of San Francisco. Examples include Recreation and Parks, Public Works, and the Police Department.
#
# Union Code-Unions represent employees in collective bargaining agreements. A job belongs to one union, although some jobs are unrepresented (usually temporarily).
#
# Union - Unions represent employees in collective bargaining agreements. A job belongs to one union, although some jobs are unrepresented (usually temporarily).
#
# Job Family Code - Job Family combines similar Jobs into meaningful groups.
#
#  Job Family - Job Family combines similar Jobs into meaningful groups.
#
#  Job Code - Jobs are defined by the Human Resources classification unit. Examples include gardeners, police officers, and accountants. Job - Jobs are defined by the Human Resources classification unit. Examples include gardeners, police officers, and accountants.
#
#   Employee Identifier - Each distinct number in the “Employee Identifier” column represents one employee. These identifying numbers are not meaningful but rather are randomly assigned for the purpose of building this dataset. The column does not appear on the Employee Compensation report hosted on openbook.sfgov.org, but that report does show one row for each employee. Employee ID has been included here to allow users to reconstruct the original report. Note that each employee’s identifier will change each time this dataset is updated, so comparisons by employee across multiple versions of the dataset are not possible.
#
#   Overtime - Amounts paid to City employees working in excess of 40 hours per week.
#
#   Other Salaries - Various irregular payments made to City employees including premium pay, incentive pay, or other one-time payments.
#
#   Retirement - City contributions to employee retirement plans.
#
#   Health/Dental - City-paid premiums to health and dental insurance plans covering City employees. To protect confidentiality as legally required, pro-rated citywide averages are presented in lieu of employee-specific health and dental benefits.
#
#   Other Benefits - Mandatory benefits paid on behalf of employees, such as Social Security (FICA and Medicare) contributions, unemployment insurance premiums, and minor discretionary benefits not included in the above categories.
#
#   Total Benefits - The sum of all benefits paid to City employees. Class- Class of Normal salaries paid to permanent or temporary City employees. Note: In the Class variable - 1 : Low range salary 2 : Mid range salary 3 : High range salary

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("train.csv")
dff = pd.read_csv("test.csv")
df.sample(5)
# Out:
#             ID Year Type  Year  Organization Group Code  \
# 148850  174610    Fiscal  2013                        1
# 88099   193759    Fiscal  2016                        4
# 25232    37893    Fiscal  2016                        1
# 138479  192359    Fiscal  2014                        1
# 80259   100377    Fiscal  2016                        2
#
#                              Organization Group Department Code  \
# 148850                        Public Protection             FIR
# 88099                          Community Health             DPH
# 25232                         Public Protection             POL
# 138479                        Public Protection             CRT
# 80259   Public Works, Transportation & Commerce             MTA
#
#                            Department  Union Code  \
# 148850            FIR Fire Department         798
# 88099               DPH Public Health         163
# 25232                      POL Police         911
# 138479             CRT Superior Court         191
# 80259   MTA Municipal Transprtn Agncy         253
#
#                                                     Union Job Family Code  \
# 148850            Firefighters - Miscellaneous, Local 798            H000
# 88099   Physicians and Dentists - Spv Physician Specia...            2200
# 25232                        Police Officers' Association            Q000
# 138479                    Court Interpreters, Local 39521            SCRT
# 80259   Transport Workers - Transit Operators, Local 2...            9100
#
#         ... Job Code                         Job Employee Identifier  \
# 148850  ...     H003   EMT/Paramedic/Firefighter               18530
# 88099   ...     2233  Supervising Physician Spec                4823
# 25232   ...     Q052                  Sergeant 3                3313
# 138479  ...     620C           Court Interpreter               36206
# 80259   ...     9163            Transit Operator                6113
#
#          Overtime  Other Salaries  Retirement  Health/Dental  Other Benefits  \
# 148850    5793.49        16483.25    22715.27       12976.17         2303.72
# 88099        0.00            0.00    45686.12       13176.00        12104.73
# 25232   106232.51        20517.70    26402.01       13182.25         4658.93
# 138479      52.97         2500.00    15718.72       12516.72         6035.41
# 80259     8458.72         1494.49    17198.25       14148.33         6199.00
#
#         Total Benefits  Class
# 148850        37995.16      3
# 88099         70966.85      3
# 25232         44243.19      3
# 138479        34270.85      2
# 80259         37545.58      2
#
# [5 rows x 21 columns]

# %%
# df.drop(columns=['Year Type', 'Organization Group', 'Department', 'Union', 'Job Family', 'Job','ID','Year', 'Union Code', 'Employee Identifier', 'Department Code','Job Family Code','Job Code'], inplace=True)
# dff.drop(columns=['Year Type', 'Organization Group', 'Department', 'Union', 'Job Family', 'Job','ID','Year', 'Union Code', 'Employee Identifier', 'Department Code','Job Family Code','Job Code'], inplace=True)
# df.sample(10).T

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_5f23b_row0_col0, #T_5f23b_row1_col1, #T_5f23b_row2_col2, #T_5f23b_row3_col3, #T_5f23b_row4_col4, #T_5f23b_row5_col5, #T_5f23b_row6_col6, #T_5f23b_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5f23b_row0_col1, #T_5f23b_row0_col2, #T_5f23b_row0_col3, #T_5f23b_row0_col4, #T_5f23b_row0_col5, #T_5f23b_row0_col6, #T_5f23b_row0_col7, #T_5f23b_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5f23b_row1_col2 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_5f23b_row1_col3 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_5f23b_row1_col4 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_5f23b_row1_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_5f23b_row1_col6 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_5f23b_row1_col7 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_5f23b_row2_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_5f23b_row2_col1 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_5f23b_row2_col3, #T_5f23b_row3_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_5f23b_row2_col4 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_5f23b_row2_col5 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_5f23b_row2_col6 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_5f23b_row2_col7, #T_5f23b_row7_col2 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_5f23b_row3_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_5f23b_row3_col2, #T_5f23b_row4_col1 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_5f23b_row3_col4 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_5f23b_row3_col5 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_5f23b_row3_col6 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_5f23b_row3_col7, #T_5f23b_row7_col3 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_5f23b_row4_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_5f23b_row4_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_5f23b_row4_col3, #T_5f23b_row5_col6 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_5f23b_row4_col5 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_5f23b_row4_col6, #T_5f23b_row6_col4, #T_5f23b_row6_col7, #T_5f23b_row7_col6 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_5f23b_row4_col7 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_5f23b_row5_col0 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_5f23b_row5_col1 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_5f23b_row5_col2 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_5f23b_row5_col3 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_5f23b_row5_col4 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_5f23b_row5_col7 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_5f23b_row6_col0 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_5f23b_row6_col1 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_5f23b_row6_col2 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_5f23b_row6_col3 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_5f23b_row6_col5 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_5f23b_row7_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_5f23b_row7_col1 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_5f23b_row7_col4 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_5f23b_row7_col5 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# </style>
# <table id="T_5f23b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Organization Group Code</th>
#       <th class="col_heading level0 col1" >Overtime</th>
#       <th class="col_heading level0 col2" >Other Salaries</th>
#       <th class="col_heading level0 col3" >Retirement</th>
#       <th class="col_heading level0 col4" >Health/Dental</th>
#       <th class="col_heading level0 col5" >Other Benefits</th>
#       <th class="col_heading level0 col6" >Total Benefits</th>
#       <th class="col_heading level0 col7" >Class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f23b_level0_row0" class="row_heading level0 row0" >Organization Group Code</th>
#       <td id="T_5f23b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5f23b_row0_col1" class="data row0 col1" >-0.301712</td>
#       <td id="T_5f23b_row0_col2" class="data row0 col2" >-0.226052</td>
#       <td id="T_5f23b_row0_col3" class="data row0 col3" >-0.243119</td>
#       <td id="T_5f23b_row0_col4" class="data row0 col4" >-0.231393</td>
#       <td id="T_5f23b_row0_col5" class="data row0 col5" >0.022912</td>
#       <td id="T_5f23b_row0_col6" class="data row0 col6" >-0.202476</td>
#       <td id="T_5f23b_row0_col7" class="data row0 col7" >-0.223910</td>
#     </tr>
#     <tr>
#       <th id="T_5f23b_level0_row1" class="row_heading level0 row1" >Overtime</th>
#       <td id="T_5f23b_row1_col0" class="data row1 col0" >-0.301712</td>
#       <td id="T_5f23b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_5f23b_row1_col2" class="data row1 col2" >0.361632</td>
#       <td id="T_5f23b_row1_col3" class="data row1 col3" >0.314432</td>
#       <td id="T_5f23b_row1_col4" class="data row1 col4" >0.308647</td>
#       <td id="T_5f23b_row1_col5" class="data row1 col5" >0.061956</td>
#       <td id="T_5f23b_row1_col6" class="data row1 col6" >0.285985</td>
#       <td id="T_5f23b_row1_col7" class="data row1 col7" >0.288897</td>
#     </tr>
#     <tr>
#       <th id="T_5f23b_level0_row2" class="row_heading level0 row2" >Other Salaries</th>
#       <td id="T_5f23b_row2_col0" class="data row2 col0" >-0.226052</td>
#       <td id="T_5f23b_row2_col1" class="data row2 col1" >0.361632</td>
#       <td id="T_5f23b_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_5f23b_row2_col3" class="data row2 col3" >0.349144</td>
#       <td id="T_5f23b_row2_col4" class="data row2 col4" >0.216293</td>
#       <td id="T_5f23b_row2_col5" class="data row2 col5" >0.054032</td>
#       <td id="T_5f23b_row2_col6" class="data row2 col6" >0.276517</td>
#       <td id="T_5f23b_row2_col7" class="data row2 col7" >0.317438</td>
#     </tr>
#     <tr>
#       <th id="T_5f23b_level0_row3" class="row_heading level0 row3" >Retirement</th>
#       <td id="T_5f23b_row3_col0" class="data row3 col0" >-0.243119</td>
#       <td id="T_5f23b_row3_col1" class="data row3 col1" >0.314432</td>
#       <td id="T_5f23b_row3_col2" class="data row3 col2" >0.349144</td>
#       <td id="T_5f23b_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_5f23b_row3_col4" class="data row3 col4" >0.787526</td>
#       <td id="T_5f23b_row3_col5" class="data row3 col5" >0.671137</td>
#       <td id="T_5f23b_row3_col6" class="data row3 col6" >0.962205</td>
#       <td id="T_5f23b_row3_col7" class="data row3 col7" >0.872818</td>
#     </tr>
#     <tr>
#       <th id="T_5f23b_level0_row4" class="row_heading level0 row4" >Health/Dental</th>
#       <td id="T_5f23b_row4_col0" class="data row4 col0" >-0.231393</td>
#       <td id="T_5f23b_row4_col1" class="data row4 col1" >0.308647</td>
#       <td id="T_5f23b_row4_col2" class="data row4 col2" >0.216293</td>
#       <td id="T_5f23b_row4_col3" class="data row4 col3" >0.787526</td>
#       <td id="T_5f23b_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_5f23b_row4_col5" class="data row4 col5" >0.606259</td>
#       <td id="T_5f23b_row4_col6" class="data row4 col6" >0.888821</td>
#       <td id="T_5f23b_row4_col7" class="data row4 col7" >0.798186</td>
#     </tr>
#     <tr>
#       <th id="T_5f23b_level0_row5" class="row_heading level0 row5" >Other Benefits</th>
#       <td id="T_5f23b_row5_col0" class="data row5 col0" >0.022912</td>
#       <td id="T_5f23b_row5_col1" class="data row5 col1" >0.061956</td>
#       <td id="T_5f23b_row5_col2" class="data row5 col2" >0.054032</td>
#       <td id="T_5f23b_row5_col3" class="data row5 col3" >0.671137</td>
#       <td id="T_5f23b_row5_col4" class="data row5 col4" >0.606259</td>
#       <td id="T_5f23b_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_5f23b_row5_col6" class="data row5 col6" >0.796860</td>

# %%
x_train = df.drop(columns=['Class'])
y_train = df['Class']
x_test = dff

# %%
from sklearn import preprocessing
def convert(data):
    number = preprocessing.LabelEncoder()
    df['Organization Group Code'] = number.fit_transform(df['Organization Group Code'])
    df['Overtime'] = number.fit_transform(df['Overtime'])
    df['Other Salaries'] = number.fit_transform(df['Other Salaries'])
    df['Retirement'] = number.fit_transform(df['Retirement'])
    df['Health/Dental'] = number.fit_transform(df['Health/Dental'])
    df['Other Benefits'] = number.fit_transform(df['Other Benefits'])
    df['Total Benefits'] = number.fit_transform(df['Total Benefits'])
    # df['Other Benefits'] = number.fit_transform(df['Other Benefits'])
    # data['Source'] = number.fit_transform(data.Source)
    data=data.fillna(0)
    return data

x_train=convert(x_train)
x_test=convert(x_test)

# %%
# x_train= np.asarray(x_train)

x_train= np.asarray(x_train).astype(np.float32)
from tensorflow.keras.utils import to_categorical 

y_train1 = to_categorical(y_train, 4)
y_train1=np.asarray(y_train1)
type(x_train)
# Out:
# numpy.ndarray

# %%
import tensorflow as tf
from tensorflow.keras.layers import  Dense, Dropout
from tensorflow.keras.models import Sequential
tf.keras.backend.clear_session()
model = Sequential()
# Apply Dropout with 0.2 probability
# Add Fully Connected Layer with 128 units and activation function as 'relu'
model.add(Dense(1500, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(35, activation='relu'))
#Add Fully Connected Layer with 10 units and activation function as 'softmax'
model.add(Dropout(rate=0.2))
model.add(Dense(1, activation='softmax'))
# Compile the model
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
# Use earlystopping
# from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
# callback = tensorflow.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=2, min_delta=0.01)
# Fit the model
model.fit(x=x_train, y=y_train, batch_size=32, epochs=10) #,  callbacks=[callback])
# let`s train for few more epochs to improve the accuracy
# model.evaluate(X_test, y_test)
# CNN_train_acc = model.evaluate(x_train, y_train)[1]
# CNN_test_acc = model.evaluate(x_test, y_test)[1]
# CNN_loss = model1.evaluate(x_test, y_test)[0]
# final_df.loc[len(final_df.index)] = ['CNN' , CNN_train_acc, CNN_test_acc, CNN_loss]
# final_df
# Out:
# Epoch 1/10
# 4659/4659 [==============================] - 16s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3265
# Epoch 2/10
# 4659/4659 [==============================] - 20s 4ms/step - loss: 0.0000e+00 - accuracy: 0.3265
# Epoch 3/10
# 4659/4659 [==============================] - 18s 4ms/step - loss: 0.0000e+00 - accuracy: 0.3265
# Epoch 4/10
# 4659/4659 [==============================] - 16s 4ms/step - loss: 0.0000e+00 - accuracy: 0.3265
# Epoch 5/10
# 4659/4659 [==============================] - 16s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3265
# Epoch 6/10
# 4659/4659 [==============================] - 16s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3265
# Epoch 7/10
# 4659/4659 [==============================] - 17s 4ms/step - loss: 0.0000e+00 - accuracy: 0.3265
# Epoch 8/10
# 4659/4659 [==============================] - 18s 4ms/step - loss: 0.0000e+00 - accuracy: 0.3265
# Epoch 9/10
# 4659/4659 [==============================] - 12s 3ms/step - loss: 0.0000e+00 - accuracy: 0.3265
# Epoch 10/10
# 4659/4659 [==============================] - 18s 4ms/step - loss: 0.0000e+00 - accuracy: 0.3265

# %%
import pyttsx3
text = pyttsx3.init()
s = 'The code is Compiled in one'
text.say(s)
text.runAndWait()

# %%
# model.fit(x_train, y_train, batch_size = 32, epochs= 20, initial_epoch=5)
model.evaluate(x_train, y_train)
Y_PRED = model.predict(x_test)

# %%
test = pd.read_csv("test.csv")

# %%
submit = test['ID']

# %%
submit.append(pd.Series(Y_PRED))
submit.sample(6)

# %%
submit.to_csv('sub1.csv')

# %%
ddf = pd.read_csv('test.csv')

# %%
ddf.sample(10)
